# %%
# !pip install datasets tqdm scikit-learn
# Out:
# Requirement already satisfied: datasets in c:\users\carlos\documents\git\llms\.env\lib\site-packages (2.14.5)
# Requirement already satisfied: tqdm in c:\users\carlos\documents\git\llms\.env\lib\site-packages (4.66.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (1.24.1)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (2.1.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (2.28.1)
# Requirement already satisfied: xxhash in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<2023.9.0,>=2023.1.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from fsspec[http]<2023.9.0,>=2023.1.0->datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (3.8.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (0.18.0)
# Requirement already satisfied: packaging in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: colorama in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from tqdm) (0.4.6)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Downloading scipy-1.11.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.1 MB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\carlos\documents\git\llms\.env\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading scikit_learn-1.3.2-cp311-cp311-win_amd64.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.7/9.2 MB 23.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.1/9.2 MB 39.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.2 MB 54.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 53.5 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    --------------------------------------- 302.2/302.2 kB 19.5 MB/s eta 0:00:00
# Downloading scipy-1.11.3-cp311-cp311-win_amd64.whl (44.1 MB)
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    ---- ----------------------------------- 4.5/44.1 MB 95.6 MB/s eta 0:00:01
#    -------- ------------------------------- 8.9/44.1 MB 94.7 MB/s eta 0:00:01
#    ------------ --------------------------- 13.3/44.1 MB 93.0 MB/s eta 0:00:01
#    --------------- ------------------------ 17.3/44.1 MB 93.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 17.9/44.1 MB 65.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 19.6/44.1 MB 59.5 MB/s eta 0:00:01
#    -------------------- ------------------- 22.9/44.1 MB 54.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 26.4/44.1 MB 50.4 MB/s eta 0:00:01
#    --------------------------- ------------ 30.0/44.1 MB 81.8 MB/s eta 0:00:01
#    ------------------------------ --------- 33.4/44.1 MB 81.8 MB/s eta 0:00:01
#    -------------------------------- ------- 36.2/44.1 MB 72.6 MB/s eta 0:00:01
#    ------------------------------------ --- 39.8/44.1 MB 73.1 MB/s eta 0:00:01
#    -------------------------------------- - 42.9/44.1 MB 73.1 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------- 44.1/44.1 MB 38.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.3.2 scipy-1.11.3 threadpoolctl-3.2.0

# %%
from datasets import load_dataset
import datasets

# %%
dataset = load_dataset("pauri32/fiqa-2018")

# %%
datasets.concatenate_datasets([dataset["train"], dataset["validation"] ,dataset["test"] ])
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'snippets', 'target', 'sentiment_score', 'aspects', 'format', 'label'],
#         num_rows: 961
#     })
#     validation: Dataset({
#         features: ['sentence', 'snippets', 'target', 'sentiment_score', 'aspects', 'format', 'label'],
#         num_rows: 102
#     })
#     test: Dataset({
#         features: ['sentence', 'snippets', 'target', 'sentiment_score', 'aspects', 'format', 'label'],
#         num_rows: 150
#     })
# })

# %% [markdown]
# # Label values:
# 0: positive
#
# 1: neutral
#
# 2: negative
#
# ## Todo
#
# refactor this function to use label

# %%
from sklearn.metrics import accuracy_score,f1_score
from datasets import load_dataset
from tqdm import tqdm


def format_example(example: dict) -> dict:
    context = f"Instruction: {example['instruction']}\n"
    if example.get("input"):
        context += f"Input: {example['input']}\n"
    context += "Answer: "
    target = example["output"]
    return {"context": context, "target": target}

def change_target(x):
    if 'positive' in x or 'Positive' in x:
        return 'positive'
    elif 'negative' in x or 'Negative' in x:
        return 'negative'
    else:
        return 'neutral'


def test_fiqa(model, tokenizer, batch_size = 8):
    dataset = load_dataset('pauri32/fiqa-2018')
    dataset = dataset["test"]
    dataset = dataset.to_pandas()
    dataset["output"] = dataset['label']
    dataset["instruction"] = "What is the sentiment of this news? Please choose an answer from {negative/neutral/positive}."

    dataset = dataset[['sentence', 'output', 'instruction']]
    dataset.columns = ['input', 'output', 'instruction']
    dataset[['context', 'target']] = dataset.apply(format_example, axis = 1, result_type="expand")

    # print example
    print(f"\n\nPrompt example:\n{dataset['context'][1]}\n\n")

    context = dataset['context'].tolist()
    total_steps = dataset.shape[0]//batch_size + 1
    print(f"Total len: {len(context)}. Batchsize: {batch_size}. Total steps: {total_steps}")

    out_text_list = []

    for i in tqdm(range(total_steps)):
        tmp_context = context[i* batch_size:(i+1)* batch_size]
        tokens = tokenizer(tmp_context, return_tensors='pt', padding=True, max_length=512)
        for k in tokens.keys():
            tokens[k] = tokens[k].cuda()
        
        res = model.generate(**tokens, max_length=512)
        res_sentences = tokenizer.batch_decode(res)
        out_text = [o.split("Answer: ")[1] for o in res_sentences]
        out_text_list += out_text
        torch.cuda.empty_cache()

    dataset["out_text"] = out_text_list
    dataset["new_target"] = dataset["target"].apply(change_target)
    dataset["new_out"] = dataset["out_text"].apply(change_target)

    acc = accuracy_score(dataset["new_target"], dataset["new_out"])
    f1_macro = f1_score(dataset["new_target"], dataset["new_out"], average = "macro")
    f1_micro = f1_score(dataset["new_target"], dataset["new_out"], average = "micro")
    f1_weighted = f1_score(dataset["new_target"], dataset["new_out"], average = "weighted")

    print(f"Acc: {acc}. F1 macro: {f1_macro}. F1 micro: {f1_micro}. F1 weighted (BloombergGPT): {f1_weighted}. ")

    return dataset

# %%
test_fiqa(None, None)
# Out:
# Prompt example:
# Instruction: What is the sentiment of this news? Please choose an answer from {negative/neutral/positive}.
# Input: @gakrum nice chart shows distinctive down channel not a dip.. where do you see the bottom? $SPY ..$150? ..$130?
# Answer:
#
#
# Total len: 150. Batchsize: 8. Total steps: 19
#   0%|          | 0/19 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Carlos\Documents\git\llms\Benchmark.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Carlos/Documents/git/llms/Benchmark.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> test_fiqa(None, None)
#
# c:\Users\Carlos\Documents\git\llms\Benchmark.ipynb Cell 7 line 4
#      <a href='vscode-notebook-cell:/c%3A/Users/Carlos/Documents/git/llms/Benchmark.ipynb#X11sZmlsZQ%3D%3D?line=42'>43</a> for i in tqdm(range(total_steps)):
#      <a href='vscode-notebook-cell:/c%3A/Users/Carlos/Documents/git/llms/Benchmark.ipynb#X11sZmlsZQ%3D%3D?line=43'>44</a>     tmp_context = context[i* batch_size:(i+1)* batch_size]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Carlos/Documents/git/llms/Benchmark.ipynb#X11sZmlsZQ%3D%3D?line=44'>45</a>     tokens = tokenizer(tmp_context, return_tensors='pt', padding=True, max_length=512)
#      <a href='vscode-notebook-cell:/c%3A/Users/Carlos/Documents/git/llms/Benchmark.ipynb#X11sZmlsZQ%3D%3D?line=45'>46</a>     for k in tokens.keys():
#      <a href='vscode-notebook-cell:/c%3A/Users/Carlos/Documents/git/llms/Benchmark.ipynb#X11sZmlsZQ%3D%3D?line=46'>47</a>         tokens[k] = tokens[k].cuda()
#
# TypeError: 'NoneType' object is not callable

# %%
test_fiqa(None, None).query('label == 1')
# Out:
#                                               sentence  \
# 10   Sold some $TSLA Puts this morning Closed them ...
# 12   RT @tomhend777 $MU needs to hold here -Broken ...
# 14   Valeant Names Interim Leader as CEO Remains Ho...
# 16   Why $TWTR is doomed in 1 chart $FB $GOOG  http...
# 18   AB InBev to Sell SABMiller Stake in China's Sn...
# 21   Whitbread boss Andy Harrison defends sales fal...
# 23   MillerCoors Board Names Gavin Hattersley Inter...
# 27   GlaxoSmithKline starts hunt for successor to C...
# 30   Mylan Appoints Ranjan Ray Chaudhuri as Global ...
# 36   Keith Skeoch to step up as David Nish quits as...
# 39   $UBNT still having some trouble at the resista...
# 41   AB InBev to sell more SAB assets as seeks EU d...
# 42   HSBC shakes up board with two new business chi...
# 44           $RAD All my charts are flashing oversold.
# 54   Valeant Said to Name New CEO With Pearson Stil...
# 60   Petrofac share price rises despite ÃÂ£30m cos...
# 61    U.S. Debt Lures Schroders as ECB Depresses Rates
# 62   $YHOO fishy action. New party interested (Dail...
# 68   Royal Mail turnaround proving expensive in tou...
# 70   Coke dividend - 3%. Google dividend - 0%. For ...
# 74   Whats up with $LULU?  Numbers looked good, not...
# 77   $PAY 2nd time test of the 21.20-30 b/o zone.  ...
# 80   CompaniesHoward Davies appointment as RBS dire...
# 82   volatility squeeze in $AAPL. I hope it gets re...
# 85   $RIG whos ever pushing this is crazy, get read...
# 86   $AGN and $PYPL under pressure along with the m...
# 87   Rio Tinto CEO says iron ore market at equilibrium
# 88   Sainsbury CFO Rogers to Replace Home Retail CE...
# 90   RBS Pays $1.7 Billion to Scrap U.K. Treasury's...
# 91     Johnson Matthey profit falls but dividend rises
# 92   UPDATE 1-Engineering firm Smiths Group confirm...
# 93   Insurer Old Mutual picks Standard Bank's Hemph...
# 95   $GILD Sandbagged the guidance so the can use t...
# 97   Sanofi poaches AstraZeneca scientist as new re...
# 98   RSA Insurance Hires Towergate's Egan as Chief ...
# 112  CompaniesDiageo stays neutral on India boardro...
# 114  $TRIP maintains Neutral rating at JP Morgan- P...
# 118  $BABA may take a few days wks months watch wha...
# 119  Should You Buy Jumbo Yielders British American...
# 122  Should You Follow Berkshire Hathaway Into Appl...
# 123  $tsla X recall not a big deal... the problem i...
# 124  Tesco share price steady as analysts weigh in ...
# 126  Market Report: Eight-day rally ends for FTSE 1...
# 127  UPDATE 1-SABMiller 2nd-quarter underlying sale...
# 130  Barclays poised to replace Sir Mike Rake as he...
# 132          BG Group appoints new CEO one month early
# 144                         $PRGN A bottom right here?
# 146  RT @jan $ARNA Don't think buyout rumor strong ...
# 147  Barclays appoints JPMorgan's Paul Compton as n...
# 148  $AAPL Now I'm glad I got stopped out of my $11...
#
#                                               snippets              target  \
# 10               ['Sold some $TSLA Puts this morning']                TSLA
# 12   ['Still not technically oversold so now big bo...                  MU
# 14      ['Interim Leader as CEO Remains Hospitalized']             Valeant
# 16                               ['doomed in 1 chart']                GOOG
# 18                      ['to Sell SABMiller Stake in']           SABMiller
# 21             ['defends sales fall as 'just a blip'']           Whitbread
# 23        ['Board Names Gavin Hattersley Interim CEO']         MillerCoors
# 27                ['starts hunt for successor to CEO']     GlaxoSmithKline
# 30   ['Appoints Ranjan Ray Chaudhuri as Global Comm...               Mylan
# 36             ['David Nish quits as chief executive']       Standard Life
# 39   ['still having some trouble at the resistance ...                UBNT
# 41                ['to sell more SAB assets as seeks']                 SAB
# 42   ['shakes up board with two new business chiefs...                HSBC
# 44            ['All my charts are flashing oversold.']                 RAD
# 54   ['Said to Name New CEO With Pearson Still Hosp...             Valeant
# 60                                ['share price rise']            Petrofac
# 61                          ['as ECB Depresses Rates']           Schroders
# 62   ['bounce & retreats. Not short by any means, b...                YHOO
# 68                              ['in tough UK market']          Royal Mail
# 70                                   ['dividend - 3%']                GOOG
# 74        ['Numbers looked good, not great, but good']                LULU
# 77                          ['Still not breaking out']                 PAY
# 80             ['appointment as RBS director delayed']                 RBS
# 82                              ['volatility squeeze']                AAPL
# 85                ['get ready for suspended dividend']                 RIG
# 86            ['under pressure along with the market']                PYPL
# 87                  ['iron ore market at equilibrium']           Rio Tinto
# 88               ['to Replace Home Retail CEO Walden']         Home Retail
# 90        ['to Scrap U.K. Treasury's Dividend Rights']                 RBS
# 91                              ['but dividend rises']     Johnson Matthey
# 92                        ['confirms CEO appointment']          Morrissons
# 93       ['picks Standard Bank's Hemphill as new CEO']       Standard Bank
# 95                         ['Sandbagged the guidance']                GILD
# 97            ['Sanofi poaches AstraZeneca scientist']              Sanofi
# 98   ['Insurance Hires Towergate's Egan as Chief Fi...           Towergate
# 112                        ['India boardroom turmoil']              Diageo
# 114                       ['maintains Neutral rating']                TRIP
# 118  ['mrkt needs to washout. to hunt well need 2 w...                TWTR
# 119                            ['Should You Buy....?']        Centrica PLC
# 122  ['Should You Follow Berkshire Hathaway Into Ap...  Berkshire Hathaway
# 123                          ['recall not a big deal']                TSLA
# 124                             ['share price steady']               Tesco
# 126  ['Market Report: Eight-day rally ends for FTSE...  Standard Chartered
# 127                         [' underlying sales rise']           SABMiller
# 130  ['poised to replace Sir Mike Rake as he heads ...            Barclays
# 132                               ['appoints new CEO']            BG Group
# 144                           ['A bottom right here?']                PRGN
# 146         ["Don't think buyout rumor strong enough"]                ARNA
# 147    ['appoints JPMorgan's Paul Compton as new COO']            Barclays
# 148               ["I'm glad I got stopped out of my"]                AAPL
#
#      sentiment_score                                            aspects  \
# 10            -0.043       ['Stock/Price Action/Bearish/Bear Position']
# 12            -0.046                       ['Stock/Technical Analysis']
# 14             0.000                          ['Corporate/Appointment']
# 16            -0.070                       ['Stock/Technical Analysis']
# 18            -0.045                       ['Stock/Signal/Sell Signal']
# 21            -0.100                                ['Corporate/Sales']
# 23             0.000                          ['Corporate/Appointment']
# 27             0.000    ['Corporate/Appointment/Executive Appointment']
# 30             0.000                          ['Corporate/Appointment']
# 36            -0.090                          ['Corporate/Appointment']
# 39             0.071                             ['Stock/Price Action']
# 41            -0.079                              ['Corporate/M&A/M&A']
# 42            -0.074                          ['Corporate/Appointment']
# 44            -0.011      ['Stock/Price Action/Current Price/Oversold']
# 54             0.015                          ['Corporate/Appointment']
# 60             0.090                             ['Stock/Price Action']
# 61             0.048                          ['Economy/Central Banks']
# 62            -0.043                             ['Stock/Price Action']
# 68            -0.057                                  ['Market/Market']
# 70            -0.066                      ['Corporate/Dividend Policy']
# 74             0.011                             ['Stock/Fundamentals']
# 77             0.093                             ['Stock/Price Action']
# 80            -0.025                          ['Corporate/Appointment']
# 82             0.042                               ['Market/Volatility]
# 85            -0.023                      ['Corporate/Dividend Policy']
# 86             0.014    ['Stock/Price Action/Bearish/Bearish Behavior']
# 87             0.000                                  ['Market/Market']
# 88             0.000                          ['Corporate/Appointment']
# 90             0.066                      ['Corporate/Dividend Policy']
# 91             0.000                      ['Corporate/Dividend Policy']
# 92             0.078                          ['Corporate/Appointment']
# 93             0.025    ['Corporate/Appointment/Executive Appointment']
# 95            -0.083  ['Corporate/Financial/Financial Results/Earnin...
# 97             0.066    ['Corporate/Appointment/Executive Appointment']
# 98             0.002    ['Corporate/Appointment/Executive Appointment']
# 112            0.000                                ['Corporate/Risks']
# 114           -0.019                  ['Stock/Coverage/AnalystRatings']
# 118           -0.055                             ['Stock/Price Action']
# 119            0.100                         ['Corporate/Rumors/Scoop']
# 122            0.000                         ['Corporate/Rumors/Scoop']
# 123            0.003                 ['Corporate/Risks/Product Recall']
# 124            0.052                             ['Stock/Price Action']
# 126            0.008                                  ['Market/Market']
# 127            0.043                          ['Corporate/Sales/Sales']
# 130            0.077                          ['Corporate/Appointment']
# 132            0.069                          ['Corporate/Appointment']
# 144            0.041                             ['Stock/Price Action']
# 146           -0.020                               ['Corporate/Rumors']
# 147            0.036                          ['Corporate/Appointment']
# 148            0.089    ['Stock/Price Action/Bearish/Bearish Behavior']
#
#        format  label
# 10       post      1
# 12       post      1
# 14   headline      1
# 16       post      1
# 18   headline      1
# 21   headline      1
# 23   headline      1
# 27   headline      1
# 30   headline      1
# 36   headline      1
# 39       post      1
# 41   headline      1
# 42   headline      1
# 44       post      1
# 54   headline      1
# 60   headline      1
# 61   headline      1
# 62       post      1
# 68   headline      1
# 70       post      1
# 74       post      1
# 77       post      1
# 80   headline      1
# 82       post      1
# 85       post      1
# 86       post      1
# 87   headline      1
# 88   headline      1
# 90   headline      1
# 91   headline      1
# 92   headline      1
# 93   headline      1
# 95       post      1
# 97   headline      1
# 98   headline      1
# 112  headline      1
# 114      post      1
# 118      post      1
# 119  headline      1
# 122  headline      1
# 123      post      1
# 124  headline      1
# 126  headline      1
# 127  headline      1
# 130  headline      1
# 132  headline      1
# 144      post      1
# 146      post      1
# 147  headline      1
# 148      post      1
